# %%
import pandas as pd
from scipy import stats
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

#leer fichero
fichero = 'https://raw.githubusercontent.com/st-srnm/quijotestilo/refs/heads/main/QUIJOTESTILO-Quijote-metricas-ALTAIR-03.json'
metricas_df = pd.read_json(fichero)    #esto es para leer el fichero json
print(metricas_df)
#Convertir valores numéricos con como a numércios con punto versión nueva ya pasa con "."
#metricas_df = metricas_df.apply(lambda col: pd.to_numeric(col.str.replace(',', '.', regex=False), errors='ignore') if col.dtype == 'object' else col)
#metricas_df = metricas_df.apply(lambda col: col.map(try_parse) if col.dtype == 'object' else col)
import pandas as pd

def safe_to_numeric(col):
    if col.dtype == 'object':
        try:
            return pd.to_numeric(col.str.replace(',', '.', regex=False))
        except Exception:
            return col
    else:
        return col

metricas_df = metricas_df.apply(safe_to_numeric)
# Out:
#      Parte  CapituloNumero ParteCapitulo          Capitulo  Total_caracteres  \
# 0        1               1         1-C01  1-C01-q04s00.txt             10477
# 1        1               2         1-C02  1-C02-q13s00.txt             12528
# 2        1               3         1-C03  1-C03-q17s01.txt             12974
# 3        1              10         1-C10  1-C10-q17s21.txt             10581
# 4        1               5         1-C05  1-C05-q11s00.txt              8756
# ..     ...             ...           ...               ...               ...
# 121      2              70         2-C70  2-C70-q28s20.txt             14569
# 122      2              72         2-C72  2-C72-q36s20.txt              9766
# 123      2              73         2-C73  2-C73-q18s13.txt              9636
# 124      2              71         2-C71  2-C71-q19s33.txt             11457
# 125      2              74         2-C74  2-C74-q24s10.txt             13784
#
#      Total_palabras Longitud_media_frases  Palabras_lexicas  \
# 0              1894                 64,64               813
# 1              2222                 70,62               989
# 2              2332                 73,38              1041
# 3              1932                 48,94               841
# 4              1612                 62,53               664
# ..              ...                   ...               ...
# 121            2622                 47,52              1133
# 122            1784                 52,79               725
# 123            1733                 49,57               719
# 124            2087                  51,8               888
# 125            2450                    51              1049
#
#      Palabras_funcionales Densidad_lexica Indice_Legilibilidad_FH  \
# 0                     917            0,43                   27,92
# 1                    1061            0,45                   22,22
# 2                    1132            0,45                    19,8
# 3                     897            0,44                   44,96
# 4                     773            0,41                   33,12
# ..                    ...             ...                     ...
# 121                  1222            0,43                   43,85
# 122                   822            0,41                      42
# 123                   808            0,41                   43,83
# 124                   970            0,43                   42,97
# 125                  1131            0,43                   40,19
#
#      Frecuencia_Quijote  Frecuencia_Sancho GrupoQS0-QSx
# 0                     4                  0       QnnSnn
# 1                    13                  0       QnnSnn
# 2                    17                  1       QnnSnn
# 3                    17                 21       QnnSnn
# 4                    11                  0       QnnSnn
# ..                  ...                ...          ...
# 121                  28                 20       QnnSnn
# 122                  36                 20       QnnSnn
# 123                  18                 13       QnnSnn
# 124                  19                 33       QnnSnn
# 125                  24                 10       QnnSnn
#
# [126 rows x 14 columns]

# %%
#Total_caracteres
print('\n******************************************')
variable = 'Total_caracteres'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')

#
#
#Total_palabras
variable = 'Total_palabras'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')

#
#
#Longitud_media_frases
variable = 'Longitud_media_frases'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')

#
#
#Palabras_lexicas
variable = 'Palabras_lexicas'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')

#
#
#Palabras_funcionales
variable = 'Palabras_funcionales'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')

#
#
#Densidad léxica
variable = 'Densidad_lexica'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')


#
#
#Indice_Legilibilidad_FH
variable = 'Indice_Legilibilidad_FH'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')

#
#
#Frecuencia_Quijote
variable = 'Frecuencia_Quijote'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
print('\n******************************************')

#
#

#Frecuencia_Sancho
variable = 'Frecuencia_Sancho'

valores_df = metricas_df
# T-test para dos grupos
grupos = valores_df['GrupoQS0-QSx'].unique()
grupo1 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[0]][variable]
grupo2 = valores_df[valores_df['GrupoQS0-QSx'] == grupos[1]][variable]
t_stat, p_value = stats.ttest_ind(grupo1, grupo2)
print('Variable = ', variable, '\n')
print(f"Se utilizó el t-test de Student para muestras independientes.")
print(f"El estadístico t es {t_stat:.3f} y el valor p es {p_value:.4f}.")
if p_value < 0.05:
     print("Existe diferencia estadísticamente significativa entre los grupos de B.")
else:
    print("No se encontró diferencia estadísticamente significativa entre los grupos de B.")
# Out:
# ******************************************
# Variable =  Total_caracteres
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es -5.561 y el valor p es 0.0000.
# Existe diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Total_palabras
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es -5.619 y el valor p es 0.0000.
# Existe diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Longitud_media_frases
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es nan y el valor p es nan.
# No se encontró diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Palabras_lexicas
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es -5.342 y el valor p es 0.0000.
# Existe diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Palabras_funcionales
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es -5.942 y el valor p es 0.0000.
# Existe diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Densidad_lexica
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es 2.197 y el valor p es 0.0299.
# Existe diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Indice_Legilibilidad_FH
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es nan y el valor p es nan.
# No se encontró diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Frecuencia_Quijote
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es 3.997 y el valor p es 0.0001.
# Existe diferencia estadísticamente significativa entre los grupos de B.
#
# ******************************************
# Variable =  Frecuencia_Sancho
#
# Se utilizó el t-test de Student para muestras independientes.
# El estadístico t es 3.347 y el valor p es 0.0011.
# Existe diferencia estadísticamente significativa entre los grupos de B.
